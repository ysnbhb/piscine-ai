# %%
import numpy as np
import math

# %%
class Neuron:
    def __init__(self, weight1, weight2, bias):
        self.weights_1 = weight1
        self.weights_2 = weight2
        self.bias = bias

    def feedforward(self, x1, x2):
        y = (x1* self.weights_1 + x2 * self.weights_2) + self.bias

        return  1 / (1 + math.exp(-y))

# %%
class OurNeuralNetwork:

    def __init__(self, neuron_h1, neuron_h2, neuron_o1):
        self.h1 = neuron_h1
        self.h2 = neuron_h2
        self.o1 = neuron_o1
    def feedforward(self, x1, x2):
        h1_out = self.h1.feedforward(x1 , x2)
        h2_out = self.h2.feedforward(x1 , x2)
        return self.o1.feedforward(h1_out , h2_out)

# %%
neuron_h1 = Neuron(1,2,-1)
neuron_h2 = Neuron(0.5,1,0)
neuron_o1 = Neuron(2,0,1)

ourNer = OurNeuralNetwork(neuron_h1 , neuron_h2 , neuron_o1)
ourNer.feedforward(2,3)
# Out:
# 0.9524917424084265
