# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from keras.layers import Dense

url = "auto-mpg.csv"
df = pd.read_csv(url, na_values="?")
df = df.drop(columns=['model year', 'origin', 'car name'])

df.dropna(inplace=True)

y = df["mpg"].values.astype(np.float32)
X = df.drop(columns=["mpg"]).values.astype(np.float32)
# Out:
# 2026-01-30 13:18:39.406248: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-01-30 13:18:39.406488: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-30 13:18:39.440718: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-30 13:18:40.242400: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-30 13:18:40.242799: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, shuffle=False
)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled  = scaler.transform(X_test)

print(X_train_scaled.shape)
X_train_scaled[:5]
# Out:
# (313, 5)
# array([[ 1.2837704 ,  0.8846664 ,  0.4869698 ,  0.4557081 , -1.1948133 ],
#        [ 1.2837704 ,  1.2812729 ,  1.3623807 ,  0.670459  , -1.3773656 ],
#        [ 1.2837704 ,  0.98612386,  0.9872047 ,  0.3784432 , -1.5599178 ],
#        [ 1.2837704 ,  0.8569961 ,  0.9872047 ,  0.37503448, -1.1948133 ],
#        [ 1.2837704 ,  0.8385493 ,  0.7370872 ,  0.39321443, -1.7424701 ]],
#       dtype=float32)

# %%
print(X_test_scaled.shape)
X_test_scaled[:5]
# Out:
# (79, 5)
# array([[-1.0025462 , -0.5541854 , -0.51349986, -0.11355221,  1.7625335 ],
#        [ 0.14061213,  0.12834683, -0.51349986,  0.31594956,  1.2513874 ],
#        [-1.0025462 , -1.0522494 , -0.81364065, -1.0395944 ,  0.19258395],
#        [-1.0025462 , -0.71098334, -0.51349986, -0.44533664,  0.08305253],
#        [-1.0025462 , -0.8401111 , -0.88867587, -0.63736254,  0.8132616 ]],
#       dtype=float32)

# %%
model = Sequential()
model.add(Dense(30, input_dim=5, activation='sigmoid'))
model.add(Dense(30, activation='sigmoid'))
model.add(Dense(1))

model.compile(
    loss='mean_squared_error',
    optimizer='adam',
    metrics=['mean_absolute_error']
)

model.fit(
    X_train_scaled, y_train,
    epochs=200,
    batch_size=32,
    verbose=0
)

loss, mae = model.evaluate(X_test_scaled, y_test, verbose=0)

print("Test MAE:", mae)
# Out:
# /home/saljaoui/keras-2/venv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2026-01-30 13:18:40.449218: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Test MAE: 8.114667892456055
