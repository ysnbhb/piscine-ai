# %%
import spacy
import numpy as np

nlp = spacy.load("en_core_web_sm")

doc = nlp("car")
v = doc[0].vector

print("Shape:", v.shape)
print("Sum:", v[:20].sum(dtype=np.float64).as_integer_ratio())
# Out:
# Shape: (96,)
# Sum: (99959115, 33554432)
