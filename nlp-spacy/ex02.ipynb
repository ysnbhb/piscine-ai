# %%
import spacy

nlp = spacy.load("en_core_web_sm")
text = "Tokenize this sentence. And this one too."
doc = nlp(text)

for token in doc:
    print(token.text)
    # print(token.pos_)
    # print(token.lemma_)
    # print(token.is_punct)
    # print(token.i)
# Out:
# Tokenize
# this
# sentence
# .
# And
# this
# one
# too
# .
